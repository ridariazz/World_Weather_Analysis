# %%
# Import all dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
import time
from scipy.stats import linregress
import gmaps

# %%
# Import the requests library.
import requests

# %%
# Import API keys 
from config import g_key
from config import weather_api_key

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Using citipy to find the nearest cities
# Using a coordinate list 
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 760

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities 
for i, city in enumerate(cities):

     # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 1 | cidreira
# Processing Record 3 of Set 1 | wanning
# Processing Record 4 of Set 1 | dabat
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | zolotkovo
# Processing Record 7 of Set 1 | souillac
# Processing Record 8 of Set 1 | meulaboh
# Processing Record 9 of Set 1 | minab
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | port-gentil
# Processing Record 13 of Set 1 | lorengau
# Processing Record 14 of Set 1 | victoria
# Processing Record 15 of Set 1 | white rock
# Processing Record 16 of Set 1 | smolensk
# Processing Record 17 of Set 1 | makat
# Processing Record 18 of Set 1 | broken hill
# Processing Record 19 of Set 1 | pahrump
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 1 | ilulissat
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | manzanillo
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | sicamous
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | zgierz
# Processing Record 33 of Set 1 | provideniya
# Processing Record 34 of Set 1 | quebo
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | kavaratti
# Processing Record 38 of Set 1 | utete
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | banda aceh
# Processing Record 42 of Set 1 | abeche
# Processing Record 43 of Set 1 | hasaki
# Processing Record 44 of Set 1 | kabare
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | san miguel
# Processing Record 49 of Set 1 | sinnamary
# Processing Record 50 of Set 1 | vestmanna
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | erenhot
# Processing Record 3 of Set 2 | lianzhou
# Processing Record 4 of Set 2 | kirakira
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | longyearbyen
# Processing Record 8 of Set 2 | ormond beach
# Processing Record 9 of Set 2 | bac lieu
# Processing Record 10 of Set 2 | paita
# Processing Record 11 of Set 2 | laguna
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | ancud
# Processing Record 14 of Set 2 | thessalon
# Processing Record 15 of Set 2 | batemans bay
# Processing Record 16 of Set 2 | kawalu
# Processing Record 17 of Set 2 | andros town
# Processing Record 18 of Set 2 | dubbo
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | norman wells
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | lebu
# Processing Record 23 of Set 2 | havelock
# Processing Record 24 of Set 2 | west wendover
# Processing Record 25 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 2 | katherine
# Processing Record 27 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | quelimane
# Processing Record 30 of Set 2 | corinto
# Processing Record 31 of Set 2 | kavieng
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | sorong
# Processing Record 34 of Set 2 | tazovskiy
# Processing Record 35 of Set 2 | yellowknife
# Processing Record 36 of Set 2 | petrovskoye
# Processing Record 37 of Set 2 | alice springs
# Processing Record 38 of Set 2 | sobolevo
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | kotaparh
# Processing Record 41 of Set 2 | kysyl-syr
# Processing Record 42 of Set 2 | rajsamand
# Processing Record 43 of Set 2 | klyuchi
# Processing Record 44 of Set 2 | warrnambool
# Processing Record 45 of Set 2 | juifang
# City not found. Skipping...
# Processing Record 46 of Set 2 | tocopilla
# Processing Record 47 of Set 2 | uruzgan
# Processing Record 48 of Set 2 | portland
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | carauari
# Processing Record 1 of Set 3 | tuktoyaktuk
# Processing Record 2 of Set 3 | faanui
# Processing Record 3 of Set 3 | kloulklubed
# Processing Record 4 of Set 3 | pisco
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | jumla
# Processing Record 7 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | cape town
# Processing Record 10 of Set 3 | naze
# Processing Record 11 of Set 3 | villa carlos paz
# Processing Record 12 of Set 3 | zyryanka
# Processing Record 13 of Set 3 | liku
# Processing Record 14 of Set 3 | bria
# Processing Record 15 of Set 3 | brownsville
# Processing Record 16 of Set 3 | ehingen
# Processing Record 17 of Set 3 | huilong
# Processing Record 18 of Set 3 | havoysund
# Processing Record 19 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 3 | adrar
# Processing Record 21 of Set 3 | bilasipara
# Processing Record 22 of Set 3 | pimentel
# Processing Record 23 of Set 3 | la ronge
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | constantine
# Processing Record 26 of Set 3 | salalah
# Processing Record 27 of Set 3 | ahipara
# Processing Record 28 of Set 3 | upernavik
# Processing Record 29 of Set 3 | arraial do cabo
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | cockburn town
# Processing Record 32 of Set 3 | kawhia
# Processing Record 33 of Set 3 | gat
# Processing Record 34 of Set 3 | pitimbu
# Processing Record 35 of Set 3 | gouyave
# Processing Record 36 of Set 3 | maloshuyka
# City not found. Skipping...
# Processing Record 37 of Set 3 | san patricio
# Processing Record 38 of Set 3 | praia
# Processing Record 39 of Set 3 | inhambane
# Processing Record 40 of Set 3 | qaanaaq
# Processing Record 41 of Set 3 | kenai
# Processing Record 42 of Set 3 | cherskiy
# Processing Record 43 of Set 3 | tasiilaq
# Processing Record 44 of Set 3 | phalaborwa
# Processing Record 45 of Set 3 | carnarvon
# Processing Record 46 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 3 | harnosand
# Processing Record 48 of Set 3 | airai
# Processing Record 49 of Set 3 | nargana
# Processing Record 50 of Set 3 | hit
# Processing Record 1 of Set 4 | esperance
# Processing Record 2 of Set 4 | katsuura
# Processing Record 3 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 4 | rome
# Processing Record 5 of Set 4 | klaksvik
# Processing Record 6 of Set 4 | kaitangata
# Processing Record 7 of Set 4 | east stroudsburg
# Processing Record 8 of Set 4 | nemuro
# Processing Record 9 of Set 4 | jamsa
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | ponta do sol
# Processing Record 12 of Set 4 | nantucket
# Processing Record 13 of Set 4 | georgetown
# Processing Record 14 of Set 4 | rincon
# Processing Record 15 of Set 4 | esso
# Processing Record 16 of Set 4 | geraldton
# Processing Record 17 of Set 4 | konstantinovka
# Processing Record 18 of Set 4 | saint-gabriel
# Processing Record 19 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 4 | saskylakh
# Processing Record 21 of Set 4 | havre
# Processing Record 22 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 4 | xuddur
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | ilinskiy
# Processing Record 26 of Set 4 | sisimiut
# Processing Record 27 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 4 | fukue
# Processing Record 29 of Set 4 | port augusta
# Processing Record 30 of Set 4 | pimenta bueno
# Processing Record 31 of Set 4 | boa vista
# Processing Record 32 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 4 | tigil
# Processing Record 34 of Set 4 | caravelas
# Processing Record 35 of Set 4 | awbari
# Processing Record 36 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 4 | hobart
# Processing Record 38 of Set 4 | castro
# Processing Record 39 of Set 4 | gualeguaychu
# Processing Record 40 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 4 | talcahuano
# Processing Record 42 of Set 4 | nome
# Processing Record 43 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 44 of Set 4 | touros
# Processing Record 45 of Set 4 | batticaloa
# Processing Record 46 of Set 4 | mocuba
# Processing Record 47 of Set 4 | mahebourg
# Processing Record 48 of Set 4 | pokhara
# Processing Record 49 of Set 4 | bartlesville
# Processing Record 50 of Set 4 | camana
# Processing Record 1 of Set 5 | lagoa
# Processing Record 2 of Set 5 | nexo
# Processing Record 3 of Set 5 | saint anthony
# Processing Record 4 of Set 5 | smithers
# Processing Record 5 of Set 5 | pangnirtung
# Processing Record 6 of Set 5 | verkhnyaya inta
# Processing Record 7 of Set 5 | itagiba
# Processing Record 8 of Set 5 | tiznit
# Processing Record 9 of Set 5 | formosa
# Processing Record 10 of Set 5 | tuensang
# Processing Record 11 of Set 5 | narsaq
# Processing Record 12 of Set 5 | chokurdakh
# Processing Record 13 of Set 5 | grenaa
# Processing Record 14 of Set 5 | aginskoye
# Processing Record 15 of Set 5 | kaeo
# Processing Record 16 of Set 5 | blairmore
# Processing Record 17 of Set 5 | bengkulu
# Processing Record 18 of Set 5 | san quintin
# Processing Record 19 of Set 5 | bud
# Processing Record 20 of Set 5 | atambua
# Processing Record 21 of Set 5 | khandyga
# Processing Record 22 of Set 5 | labuhan
# Processing Record 23 of Set 5 | emerald
# Processing Record 24 of Set 5 | rawson
# Processing Record 25 of Set 5 | talnakh
# Processing Record 26 of Set 5 | greer
# Processing Record 27 of Set 5 | vila velha
# Processing Record 28 of Set 5 | waddan
# Processing Record 29 of Set 5 | san jose de guanipa
# Processing Record 30 of Set 5 | burley
# Processing Record 31 of Set 5 | bo
# City not found. Skipping...
# Processing Record 32 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 33 of Set 5 | makhachkala
# Processing Record 34 of Set 5 | sao joao da barra
# Processing Record 35 of Set 5 | pacific grove
# Processing Record 36 of Set 5 | arica
# Processing Record 37 of Set 5 | padang
# Processing Record 38 of Set 5 | port hardy
# Processing Record 39 of Set 5 | san antero
# Processing Record 40 of Set 5 | nibe
# Processing Record 41 of Set 5 | yevpatoriya
# Processing Record 42 of Set 5 | hope
# Processing Record 43 of Set 5 | ust-kuyga
# Processing Record 44 of Set 5 | rio grande
# Processing Record 45 of Set 5 | kudat
# Processing Record 46 of Set 5 | kodiak
# Processing Record 47 of Set 5 | cam ranh
# Processing Record 48 of Set 5 | codrington
# Processing Record 49 of Set 5 | coquimbo
# Processing Record 50 of Set 5 | coahuayana
# Processing Record 1 of Set 6 | bethel
# Processing Record 2 of Set 6 | tura
# Processing Record 3 of Set 6 | acapulco
# Processing Record 4 of Set 6 | botro
# Processing Record 5 of Set 6 | le vauclin
# Processing Record 6 of Set 6 | scottsbluff
# Processing Record 7 of Set 6 | jalu
# Processing Record 8 of Set 6 | dzhebariki-khaya
# Processing Record 9 of Set 6 | half moon bay
# Processing Record 10 of Set 6 | loreto
# Processing Record 11 of Set 6 | bathsheba
# Processing Record 12 of Set 6 | namibe
# Processing Record 13 of Set 6 | ayotzintepec
# Processing Record 14 of Set 6 | anklam
# Processing Record 15 of Set 6 | pevek
# Processing Record 16 of Set 6 | sampit
# Processing Record 17 of Set 6 | hailun
# Processing Record 18 of Set 6 | santa fe
# Processing Record 19 of Set 6 | mao
# Processing Record 20 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 6 | kangaatsiaq
# Processing Record 22 of Set 6 | sire
# Processing Record 23 of Set 6 | mana
# Processing Record 24 of Set 6 | qasigiannguit
# Processing Record 25 of Set 6 | shu
# Processing Record 26 of Set 6 | boyabat
# Processing Record 27 of Set 6 | camargo
# Processing Record 28 of Set 6 | zajecar
# Processing Record 29 of Set 6 | gejiu
# Processing Record 30 of Set 6 | mount gambier
# Processing Record 31 of Set 6 | sahuaripa
# Processing Record 32 of Set 6 | lima
# Processing Record 33 of Set 6 | ust-tsilma
# Processing Record 34 of Set 6 | vondrozo
# Processing Record 35 of Set 6 | miandrivazo
# Processing Record 36 of Set 6 | hobyo
# Processing Record 37 of Set 6 | oranjemund
# Processing Record 38 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 39 of Set 6 | kasugai
# Processing Record 40 of Set 6 | avera
# Processing Record 41 of Set 6 | vladimiro-aleksandrovskoye
# Processing Record 42 of Set 6 | anadyr
# Processing Record 43 of Set 6 | ayame
# Processing Record 44 of Set 6 | rocha
# Processing Record 45 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 46 of Set 6 | tres passos
# Processing Record 47 of Set 6 | kolosovka
# Processing Record 48 of Set 6 | horodyshche
# Processing Record 49 of Set 6 | peruibe
# Processing Record 50 of Set 6 | oranjestad
# Processing Record 1 of Set 7 | suntar
# Processing Record 2 of Set 7 | xinzhou
# Processing Record 3 of Set 7 | zhigansk
# Processing Record 4 of Set 7 | sola
# Processing Record 5 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 7 | haines junction
# Processing Record 7 of Set 7 | waipawa
# Processing Record 8 of Set 7 | sitka
# Processing Record 9 of Set 7 | taltal
# Processing Record 10 of Set 7 | alice town
# Processing Record 11 of Set 7 | saint george
# Processing Record 12 of Set 7 | scharnstein
# Processing Record 13 of Set 7 | maniitsoq
# Processing Record 14 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 7 | vao
# Processing Record 16 of Set 7 | tiksi
# Processing Record 17 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 7 | anchorage
# Processing Record 19 of Set 7 | hambantota
# Processing Record 20 of Set 7 | sao felix do xingu
# Processing Record 21 of Set 7 | tomatlan
# Processing Record 22 of Set 7 | crato
# Processing Record 23 of Set 7 | ust-nera
# Processing Record 24 of Set 7 | tukrah
# Processing Record 25 of Set 7 | ngunguru
# Processing Record 26 of Set 7 | irtyshskiy
# Processing Record 27 of Set 7 | khartoum
# Processing Record 28 of Set 7 | rio gallegos
# Processing Record 29 of Set 7 | ilo
# Processing Record 30 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 7 | teplodar
# Processing Record 32 of Set 7 | cap malheureux
# Processing Record 33 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 7 | egvekinot
# Processing Record 35 of Set 7 | lisala
# Processing Record 36 of Set 7 | fort nelson
# Processing Record 37 of Set 7 | burkhala
# City not found. Skipping...
# Processing Record 38 of Set 7 | sao filipe
# Processing Record 39 of Set 7 | skjervoy
# Processing Record 40 of Set 7 | tuy hoa
# Processing Record 41 of Set 7 | liverpool
# Processing Record 42 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 7 | vanimo
# Processing Record 44 of Set 7 | cayenne
# Processing Record 45 of Set 7 | mitu
# Processing Record 46 of Set 7 | kwekwe
# Processing Record 47 of Set 7 | manicore
# Processing Record 48 of Set 7 | ambilobe
# Processing Record 49 of Set 7 | nelson bay
# Processing Record 50 of Set 7 | tecolutla
# Processing Record 1 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 8 | saldanha
# Processing Record 3 of Set 8 | tuatapere
# Processing Record 4 of Set 8 | lata
# Processing Record 5 of Set 8 | bonthe
# Processing Record 6 of Set 8 | priiskovyy
# Processing Record 7 of Set 8 | toora-khem
# Processing Record 8 of Set 8 | gobabis
# Processing Record 9 of Set 8 | manavgat
# Processing Record 10 of Set 8 | yulara
# Processing Record 11 of Set 8 | raffadali
# Processing Record 12 of Set 8 | rensvik
# Processing Record 13 of Set 8 | dzilam gonzalez
# Processing Record 14 of Set 8 | francistown
# Processing Record 15 of Set 8 | haicheng
# Processing Record 16 of Set 8 | biltine
# Processing Record 17 of Set 8 | griffith
# Processing Record 18 of Set 8 | pinyug
# Processing Record 19 of Set 8 | ramhormoz
# Processing Record 20 of Set 8 | kokkola
# Processing Record 21 of Set 8 | hay river
# Processing Record 22 of Set 8 | birao
# Processing Record 23 of Set 8 | balabac
# Processing Record 24 of Set 8 | atlantic beach
# Processing Record 25 of Set 8 | ingham
# Processing Record 26 of Set 8 | muisne
# Processing Record 27 of Set 8 | zhuhai
# Processing Record 28 of Set 8 | diamantino
# Processing Record 29 of Set 8 | dikson
# Processing Record 30 of Set 8 | timizart
# Processing Record 31 of Set 8 | saint-augustin
# Processing Record 32 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 8 | rimbey
# Processing Record 34 of Set 8 | samarai
# Processing Record 35 of Set 8 | moussoro
# Processing Record 36 of Set 8 | victor harbor
# Processing Record 37 of Set 8 | coos bay
# Processing Record 38 of Set 8 | murray bridge
# Processing Record 39 of Set 8 | clyde river
# Processing Record 40 of Set 8 | krasnokamensk
# Processing Record 41 of Set 8 | shiyan
# Processing Record 42 of Set 8 | viedma
# Processing Record 43 of Set 8 | olafsvik
# Processing Record 44 of Set 8 | kelvington
# Processing Record 45 of Set 8 | weligama
# Processing Record 46 of Set 8 | itupiranga
# Processing Record 47 of Set 8 | vysokogornyy
# Processing Record 48 of Set 8 | fortuna
# Processing Record 49 of Set 8 | srednekolymsk
# Processing Record 50 of Set 8 | karpathos
# Processing Record 1 of Set 9 | villa maria
# Processing Record 2 of Set 9 | ukiah
# Processing Record 3 of Set 9 | hamilton
# Processing Record 4 of Set 9 | santa cruz cabralia
# Processing Record 5 of Set 9 | guerrero negro
# Processing Record 6 of Set 9 | pochutla
# Processing Record 7 of Set 9 | zhaotong
# Processing Record 8 of Set 9 | ekhabi
# Processing Record 9 of Set 9 | barcelos
# Processing Record 10 of Set 9 | chissamba
# Processing Record 11 of Set 9 | araouane
# Processing Record 12 of Set 9 | peniche
# Processing Record 13 of Set 9 | burgos
# Processing Record 14 of Set 9 | hellin
# Processing Record 15 of Set 9 | kaputa
# Processing Record 16 of Set 9 | ereymentau
# Processing Record 17 of Set 9 | vestmannaeyjar
# Processing Record 18 of Set 9 | dudinka
# Processing Record 19 of Set 9 | jiuquan
# Processing Record 20 of Set 9 | kovdor
# Processing Record 21 of Set 9 | galle
# Processing Record 22 of Set 9 | yerbogachen
# Processing Record 23 of Set 9 | port lincoln
# Processing Record 24 of Set 9 | mayo
# Processing Record 25 of Set 9 | leshukonskoye
# Processing Record 26 of Set 9 | carira
# Processing Record 27 of Set 9 | svetlogorsk
# Processing Record 28 of Set 9 | high rock
# Processing Record 29 of Set 9 | conde
# Processing Record 30 of Set 9 | pandan
# Processing Record 31 of Set 9 | road town
# Processing Record 32 of Set 9 | castlegar
# Processing Record 33 of Set 9 | nylstroom
# City not found. Skipping...
# Processing Record 34 of Set 9 | bonavista
# Processing Record 35 of Set 9 | chapais
# Processing Record 36 of Set 9 | luderitz
# Processing Record 37 of Set 9 | itarema
# Processing Record 38 of Set 9 | omboue
# Processing Record 39 of Set 9 | cabedelo
# Processing Record 40 of Set 9 | natal
# Processing Record 41 of Set 9 | grand gaube
# Processing Record 42 of Set 9 | verkhnevilyuysk
# Processing Record 43 of Set 9 | miri
# Processing Record 44 of Set 9 | muli
# Processing Record 45 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 9 | concordia
# Processing Record 47 of Set 9 | torbay
# Processing Record 48 of Set 9 | carutapera
# Processing Record 49 of Set 9 | zanatepec
# City not found. Skipping...
# Processing Record 50 of Set 9 | high level
# Processing Record 1 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 10 | matamoros
# Processing Record 3 of Set 10 | atasu
# Processing Record 4 of Set 10 | ixmiquilpan
# Processing Record 5 of Set 10 | cabo san lucas
# Processing Record 6 of Set 10 | trapani
# Processing Record 7 of Set 10 | luba
# Processing Record 8 of Set 10 | san matias
# Processing Record 9 of Set 10 | aklavik
# Processing Record 10 of Set 10 | lannion
# Processing Record 11 of Set 10 | kenora
# Processing Record 12 of Set 10 | iwata
# Processing Record 13 of Set 10 | rafaela
# Processing Record 14 of Set 10 | newport beach
# Processing Record 15 of Set 10 | kondoa
# Processing Record 16 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 10 | san policarpo
# Processing Record 18 of Set 10 | sinjah
# City not found. Skipping...
# Processing Record 19 of Set 10 | pio ix
# Processing Record 20 of Set 10 | keetmanshoop
# Processing Record 21 of Set 10 | lungi
# Processing Record 22 of Set 10 | naduvattam
# Processing Record 23 of Set 10 | eyl
# Processing Record 24 of Set 10 | coihaique
# Processing Record 25 of Set 10 | santa cruz
# Processing Record 26 of Set 10 | shimoda
# Processing Record 27 of Set 10 | los llanos de aridane
# Processing Record 28 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 29 of Set 10 | ardahan
# Processing Record 30 of Set 10 | big rapids
# Processing Record 31 of Set 10 | kaduqli
# Processing Record 32 of Set 10 | suba
# Processing Record 33 of Set 10 | vila do maio
# Processing Record 34 of Set 10 | den helder
# Processing Record 35 of Set 10 | pitiquito
# Processing Record 36 of Set 10 | kemijarvi
# Processing Record 37 of Set 10 | komsomolskiy
# Processing Record 38 of Set 10 | champerico
# Processing Record 39 of Set 10 | kahului
# Processing Record 40 of Set 10 | nuuk
# Processing Record 41 of Set 10 | vung tau
# Processing Record 42 of Set 10 | hofn
# Processing Record 43 of Set 10 | sioux lookout
# Processing Record 44 of Set 10 | kefar tavor
# Processing Record 45 of Set 10 | arawa
# Processing Record 46 of Set 10 | barra patuca
# Processing Record 47 of Set 10 | kamenka
# Processing Record 48 of Set 10 | asau
# Processing Record 49 of Set 10 | kota kinabalu
# Processing Record 50 of Set 10 | leningradskiy
# Processing Record 1 of Set 11 | constitucion
# Processing Record 2 of Set 11 | kushima
# Processing Record 3 of Set 11 | north myrtle beach
# Processing Record 4 of Set 11 | derbent
# Processing Record 5 of Set 11 | bell ville
# Processing Record 6 of Set 11 | riaba
# City not found. Skipping...
# Processing Record 7 of Set 11 | primalkinskoye
# Processing Record 8 of Set 11 | charters towers
# Processing Record 9 of Set 11 | baykit
# Processing Record 10 of Set 11 | yuzhou
# Processing Record 11 of Set 11 | teacapan
# Processing Record 12 of Set 11 | uvira
# Processing Record 13 of Set 11 | korla
# Processing Record 14 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 15 of Set 11 | billings
# Processing Record 16 of Set 11 | nanortalik
# Processing Record 17 of Set 11 | swift current
# Processing Record 18 of Set 11 | kutum
# Processing Record 19 of Set 11 | havre-saint-pierre
# Processing Record 20 of Set 11 | oussouye
# Processing Record 21 of Set 11 | namatanai
# Processing Record 22 of Set 11 | biak
# Processing Record 23 of Set 11 | sakaiminato
# Processing Record 24 of Set 11 | altay
# Processing Record 25 of Set 11 | sergeyevka
# Processing Record 26 of Set 11 | bandarbeyla
# Processing Record 27 of Set 11 | ginir
# Processing Record 28 of Set 11 | honiara
# Processing Record 29 of Set 11 | leninsk
# Processing Record 30 of Set 11 | minervino murge
# Processing Record 31 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 32 of Set 11 | doha
# Processing Record 33 of Set 11 | saint-pierre
# Processing Record 34 of Set 11 | taoudenni
# Processing Record 35 of Set 11 | turukhansk
# Processing Record 36 of Set 11 | graaff-reinet
# Processing Record 37 of Set 11 | nizwa
# Processing Record 38 of Set 11 | acari
# Processing Record 39 of Set 11 | englewood
# Processing Record 40 of Set 11 | kempsey
# Processing Record 41 of Set 11 | hami
# Processing Record 42 of Set 11 | maceio
# Processing Record 43 of Set 11 | alofi
# Processing Record 44 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 11 | baindur
# Processing Record 46 of Set 11 | dumas
# Processing Record 47 of Set 11 | umm lajj
# Processing Record 48 of Set 11 | porto novo
# Processing Record 49 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 11 | kupang
# Processing Record 1 of Set 12 | margate
# Processing Record 2 of Set 12 | suchilquitongo
# City not found. Skipping...
# Processing Record 3 of Set 12 | te anau
# Processing Record 4 of Set 12 | iqaluit
# Processing Record 5 of Set 12 | praia da vitoria
# Processing Record 6 of Set 12 | roald
# Processing Record 7 of Set 12 | san cristobal
# Processing Record 8 of Set 12 | lehola
# Processing Record 9 of Set 12 | goderich
# Processing Record 10 of Set 12 | stephenville crossing
# Processing Record 11 of Set 12 | bage
# Processing Record 12 of Set 12 | cairns
# Processing Record 13 of Set 12 | boma
# Processing Record 14 of Set 12 | altus
# Processing Record 15 of Set 12 | todos santos
# Processing Record 16 of Set 12 | zehdenick
# Processing Record 17 of Set 12 | umea
# Processing Record 18 of Set 12 | banjar
# Processing Record 19 of Set 12 | ostrovnoy
# Processing Record 20 of Set 12 | zemio
# Processing Record 21 of Set 12 | flin flon
# Processing Record 22 of Set 12 | santa maria
# Processing Record 23 of Set 12 | san gabriel
# Processing Record 24 of Set 12 | araxa
# Processing Record 25 of Set 12 | mizoch
# Processing Record 26 of Set 12 | kieta
# Processing Record 27 of Set 12 | kapit
# Processing Record 28 of Set 12 | togur
# Processing Record 29 of Set 12 | novyy urengoy
# Processing Record 30 of Set 12 | bina-etawa
# City not found. Skipping...
# Processing Record 31 of Set 12 | ano mera
# Processing Record 32 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 33 of Set 12 | quang ngai
# Processing Record 34 of Set 12 | khuzdar
# Processing Record 35 of Set 12 | husavik
# Processing Record 36 of Set 12 | serenje
# Processing Record 37 of Set 12 | ahuimanu
# Processing Record 38 of Set 12 | batagay-alyta
# Processing Record 39 of Set 12 | mairi
# Processing Record 40 of Set 12 | andapa
# Processing Record 41 of Set 12 | raudeberg
# Processing Record 42 of Set 12 | kuching
# Processing Record 43 of Set 12 | faya
# Processing Record 44 of Set 12 | attock
# Processing Record 45 of Set 12 | mishelevka
# Processing Record 46 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 47 of Set 12 | valle hermoso
# Processing Record 48 of Set 12 | abalak
# Processing Record 49 of Set 12 | marsh harbour
# Processing Record 50 of Set 12 | cassilandia
# Processing Record 1 of Set 13 | whitehorse
# Processing Record 2 of Set 13 | rena
# Processing Record 3 of Set 13 | tarko-sale
# Processing Record 4 of Set 13 | sazonovo
# Processing Record 5 of Set 13 | balkanabat
# Processing Record 6 of Set 13 | atoka
# Processing Record 7 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 8 of Set 13 | cuenca
# Processing Record 9 of Set 13 | kedrovyy
# Processing Record 10 of Set 13 | samarinda
# Processing Record 11 of Set 13 | kirkwall
# Processing Record 12 of Set 13 | ensenada
# Processing Record 13 of Set 13 | najran
# Processing Record 14 of Set 13 | sur
# Processing Record 15 of Set 13 | huesca
# Processing Record 16 of Set 13 | porto velho
# Processing Record 17 of Set 13 | praya
# Processing Record 18 of Set 13 | sabha
# Processing Record 19 of Set 13 | onega
# Processing Record 20 of Set 13 | karratha
# Processing Record 21 of Set 13 | kozhva
# Processing Record 22 of Set 13 | taupo
# Processing Record 23 of Set 13 | krivosheino
# Processing Record 24 of Set 13 | mlowo
# Processing Record 25 of Set 13 | san vicente de chucuri
# Processing Record 26 of Set 13 | waki
# Processing Record 27 of Set 13 | hailar
# Processing Record 28 of Set 13 | digby
# Processing Record 29 of Set 13 | hermosillo
# Processing Record 30 of Set 13 | colon
# Processing Record 31 of Set 13 | nizhnyaya tavda
# Processing Record 32 of Set 13 | christchurch
# Processing Record 33 of Set 13 | poum
# Processing Record 34 of Set 13 | burnie
# Processing Record 35 of Set 13 | vila franca do campo
# Processing Record 36 of Set 13 | guabito
# Processing Record 37 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 13 | yinchuan
# Processing Record 40 of Set 13 | iquique
# Processing Record 41 of Set 13 | toamasina
# Processing Record 42 of Set 13 | ixtapa
# Processing Record 43 of Set 13 | yelatma
# Processing Record 44 of Set 13 | mehran
# Processing Record 45 of Set 13 | careiro da varzea
# Processing Record 46 of Set 13 | chumikan
# Processing Record 47 of Set 13 | inirida
# Processing Record 48 of Set 13 | tumbes
# Processing Record 49 of Set 13 | port macquarie
# Processing Record 50 of Set 13 | hovd
# Processing Record 1 of Set 14 | asosa
# Processing Record 2 of Set 14 | vardo
# Processing Record 3 of Set 14 | mwinilunga
# Processing Record 4 of Set 14 | rietavas
# Processing Record 5 of Set 14 | revadanda
# Processing Record 6 of Set 14 | antofagasta
# Processing Record 7 of Set 14 | lavrentiya
# Processing Record 8 of Set 14 | timra
# Processing Record 9 of Set 14 | sirohi
# Processing Record 10 of Set 14 | micheweni
# Processing Record 11 of Set 14 | ponta delgada
# Processing Record 12 of Set 14 | nouadhibou
# Processing Record 13 of Set 14 | haileybury
# Processing Record 14 of Set 14 | kasempa
# Processing Record 15 of Set 14 | terney
# Processing Record 16 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 17 of Set 14 | alandur
# Processing Record 18 of Set 14 | prince rupert
# Processing Record 19 of Set 14 | shenjiamen
# Processing Record 20 of Set 14 | sveti nikole
# Processing Record 21 of Set 14 | tabuk
# Processing Record 22 of Set 14 | banes
# Processing Record 23 of Set 14 | changli
# Processing Record 24 of Set 14 | kedainiai
# Processing Record 25 of Set 14 | port hedland
# Processing Record 26 of Set 14 | hearst
# Processing Record 27 of Set 14 | khandbari
# Processing Record 28 of Set 14 | ugoofaaru
# Processing Record 29 of Set 14 | general roca
# Processing Record 30 of Set 14 | matongo
# Processing Record 31 of Set 14 | makakilo city
# Processing Record 32 of Set 14 | verkhoyansk
# Processing Record 33 of Set 14 | guadalupe victoria
# Processing Record 34 of Set 14 | aadorf
# Processing Record 35 of Set 14 | marawi
# Processing Record 36 of Set 14 | longkou
# Processing Record 37 of Set 14 | candawaga
# City not found. Skipping...
# Processing Record 38 of Set 14 | pathein
# Processing Record 39 of Set 14 | puerto escondido
# Processing Record 40 of Set 14 | nortelandia
# Processing Record 41 of Set 14 | bangui
# Processing Record 42 of Set 14 | xai-xai
# Processing Record 43 of Set 14 | magistralnyy
# Processing Record 44 of Set 14 | rio bravo
# Processing Record 45 of Set 14 | lashio
# Processing Record 46 of Set 14 | archidona
# Processing Record 47 of Set 14 | miraflores
# Processing Record 48 of Set 14 | chicontepec
# Processing Record 49 of Set 14 | burica
# City not found. Skipping...
# Processing Record 50 of Set 14 | herat
# Processing Record 1 of Set 15 | manhattan
# Processing Record 2 of Set 15 | aksarka
# Processing Record 3 of Set 15 | ust-uda
# Processing Record 4 of Set 15 | yar-sale
# Processing Record 5 of Set 15 | vicksburg
# Processing Record 6 of Set 15 | beringovskiy
# Processing Record 7 of Set 15 | noumea
# Processing Record 8 of Set 15 | tezu
# Processing Record 9 of Set 15 | oistins
# Processing Record 10 of Set 15 | okha
# Processing Record 11 of Set 15 | tessalit
# Processing Record 12 of Set 15 | yarada
# Processing Record 13 of Set 15 | lakhdenpokhya
# Processing Record 14 of Set 15 | kizema
# Processing Record 15 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 16 of Set 15 | senno
# Processing Record 17 of Set 15 | palmer
# Processing Record 18 of Set 15 | pedernales
# Processing Record 19 of Set 15 | vila nova de milfontes
# Processing Record 20 of Set 15 | agde
# Processing Record 21 of Set 15 | perth
# Processing Record 22 of Set 15 | mount pleasant
# Processing Record 23 of Set 15 | mercedes
# Processing Record 24 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 25 of Set 15 | flinders
# Processing Record 26 of Set 15 | port shepstone
# Processing Record 27 of Set 15 | isangel
# Processing Record 28 of Set 15 | ambulu
# Processing Record 29 of Set 15 | makubetsu
# Processing Record 30 of Set 15 | broome
# Processing Record 31 of Set 15 | grindavik
# Processing Record 32 of Set 15 | cascais
# Processing Record 33 of Set 15 | choma
# Processing Record 34 of Set 15 | coolum beach
# Processing Record 35 of Set 15 | kulhudhuffushi
# Processing Record 36 of Set 15 | alanya
# Processing Record 37 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 38 of Set 15 | belaya gora
# Processing Record 39 of Set 15 | gizo
# Processing Record 40 of Set 15 | gornopravdinsk
# Processing Record 41 of Set 15 | lodja
# Processing Record 42 of Set 15 | huarmey
# Processing Record 43 of Set 15 | vanavara
# Processing Record 44 of Set 15 | buta
# Processing Record 45 of Set 15 | totness
# Processing Record 46 of Set 15 | bonfim
# Processing Record 47 of Set 15 | sharjah
# Processing Record 48 of Set 15 | ilhabela
# Processing Record 49 of Set 15 | sri aman
# Processing Record 50 of Set 15 | farah
# Processing Record 1 of Set 16 | muros
# Processing Record 2 of Set 16 | phatthalung
# Processing Record 3 of Set 16 | duluth
# Processing Record 4 of Set 16 | yarensk
# Processing Record 5 of Set 16 | bayanday
# Processing Record 6 of Set 16 | yuci
# Processing Record 7 of Set 16 | biskamzha
# Processing Record 8 of Set 16 | tilichiki
# Processing Record 9 of Set 16 | bilma
# Processing Record 10 of Set 16 | juterbog
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
# Creating a Data Frame 
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Cidreira -30.1811  -50.2056     58.93        88          88        9.89
# 1    Wanning  18.8003  110.3967     83.12        78           6        3.53
# 2      Dabat  12.9842   37.7650     54.43        87          95        3.89
# 3     Atuona  -9.8000 -139.0333     76.89        74          12       13.69
# 4  Zolotkovo  55.5281   41.1053     55.74        66          87        1.99
#
#   Country                 Date
# 0      BR  2022-08-01 00:04:57
# 1      CN  2022-08-01 00:04:57
# 2      ET  2022-08-01 00:04:58
# 3      PF  2022-08-01 00:04:58
# 4      RU  2022-08-01 00:04:59

# %%
# Re-ordering the columns to depict a certain order 

new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0     Cidreira      BR  2022-08-01 00:04:57 -30.1811  -50.2056     58.93
# 1      Wanning      CN  2022-08-01 00:04:57  18.8003  110.3967     83.12
# 2        Dabat      ET  2022-08-01 00:04:58  12.9842   37.7650     54.43
# 3       Atuona      PF  2022-08-01 00:04:58  -9.8000 -139.0333     76.89
# 4    Zolotkovo      RU  2022-08-01 00:04:59  55.5281   41.1053     55.74
# ..         ...     ...                  ...      ...       ...       ...
# 697       Yuci      CN  2022-08-01 00:25:42  37.6803  112.7319     76.75
# 698  Biskamzha      RU  2022-08-01 00:25:43  53.4497   89.5272     59.58
# 699  Tilichiki      RU  2022-08-01 00:25:43  60.4667  166.1000     55.85
# 700      Bilma      NE  2022-08-01 00:25:44  18.6853   12.9164     88.63
# 701   Juterbog      DE  2022-08-01 00:25:44  51.9833   13.0833     68.70
#
#      Humidity  Cloudiness  Wind Speed
# 0          88          88        9.89
# 1          78           6        3.53
# 2          87          95        3.89
# 3          74          12       13.69
# 4          66          87        1.99
# ..        ...         ...         ...
# 697        73           0        2.24
# 698        91          63        0.47
# 699        63          78        5.93
# 700        41          80        5.53
# 701        67         100        4.74
#
# [702 rows x 9 columns]

# %%
# Export the DataFrame as a CSV file 
csv_weatherdata_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weatherdata_file, index_label="City_ID")
